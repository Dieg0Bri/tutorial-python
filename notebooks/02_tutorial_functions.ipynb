# %% [markdown]
# # Tutorial de Funciones en Python 🔧
#
# En este tutorial aprenderás:
# - Qué son las funciones y por qué son útiles
# - Cómo crear tus propias funciones
# - Parámetros y argumentos
# - Valores de retorno
# - Funciones con parámetros opcionales
# - Scope (alcance) de variables
#
# ¡Las funciones son bloques de código reutilizable que harán tu vida más fácil!

# %% [markdown]
# ## ¿Qué es una función? 🛠️
#
# Una **función** es un bloque de código que:
# - Tiene un nombre
# - Puede recibir datos de entrada (parámetros)
# - Ejecuta una tarea específica
# - Puede devolver un resultado
#
# **¿Por qué usar funciones?**
# - ✅ Evitar repetir código
# - ✅ Organizar mejor el programa
# - ✅ Fácil de mantener y corregir
# - ✅ Reutilizar código en diferentes partes
#
# **Sintaxis básica:**
# ```python
# def nombre_funcion(parametros):
#     # código de la función
#     return resultado  # opcional
# ```

# %%
# Mi primera función simple

def saludar():
    print("¡Hola! Bienvenido a Python")

# Para usar la función, la "llamamos" por su nombre
saludar()
saludar()  # Podemos llamarla tantas veces como queramos
# Out:
# ¡Hola! Bienvenido a Python
# ¡Hola! Bienvenido a Python

# %% [markdown]
# ## Funciones con parámetros 📝
#
# Los **parámetros** son variables que la función recibe para trabajar con ellos.
# Hacen las funciones más flexibles y útiles.

# %%
# Función con un parámetro
def saludar_persona(nombre):
    print(f"¡Hola {nombre}! ¿Cómo estás?")

# Función con múltiples parámetros
def presentar_persona(nombre, edad, ciudad):
    print(f"Mi nombre es {nombre}")
    print(f"Tengo {edad} años")
    print(f"Vivo en {ciudad}")

# Llamando las funciones
saludar_persona("María")
saludar_persona("Carlos")

print("\n--- Presentación ---")
presentar_persona("Ana", 25, "Madrid")

# %% [markdown]
# ## Funciones que devuelven valores ↩️
#
# Las funciones pueden devolver un resultado usando la palabra `return`.
# Este valor se puede guardar en una variable o usar directamente.

# %%
# Funciones con return

def sumar(a, b):
    resultado = a + b
    return resultado

def calcular_area_rectangulo(largo, ancho):
    area = largo * ancho
    return area

def crear_saludo(nombre):
    mensaje = f"¡Hola {nombre}, que tengas un buen día!"
    return mensaje

# Usando las funciones
suma = sumar(5, 3)
print("5 + 3 =", suma)

area = calcular_area_rectangulo(10, 5)
print("Área del rectángulo:", area, "m²")

saludo = crear_saludo("Luis")
print(saludo)

# También podemos usar el resultado directamente
print("El doble de 7 es:", sumar(7, 7))

# %% [markdown]
# ## Parámetros con valores por defecto 🎛️
#
# Podemos dar valores por defecto a los parámetros. Si no se proporciona un valor,
# se usa el valor por defecto.

# %%
# Función con parámetros por defecto
def saludar_con_idioma(nombre, idioma="español"):
    if idioma == "español":
        return f"¡Hola {nombre}!"
    elif idioma == "inglés":
        return f"Hello {nombre}!"
    elif idioma == "francés":
        return f"Bonjour {nombre}!"
    else:
        return f"¡Hola {nombre}!"

def calcular_precio_con_descuento(precio, descuento=0):
    precio_final = precio - (precio * descuento / 100)
    return precio_final

# Usando la función con y sin parámetros opcionales
print(saludar_con_idioma("Ana"))  # Usa el idioma por defecto
print(saludar_con_idioma("John", "inglés"))
print(saludar_con_idioma("Marie", "francés"))

print(f"\nPrecio sin descuento: €{calcular_precio_con_descuento(100)}")
print(f"Precio con 20% descuento: €{calcular_precio_con_descuento(100, 20)}")

# %% [markdown]
# ## Estructuras Condicionales (if, elif, else) 🤔
#
# Las **estructuras condicionales** permiten que el programa tome decisiones basadas en condiciones.
#
# **Sintaxis:**
# ```python
# if condición:
#     # código si la condición es verdadera
# elif otra_condición:
#     # código si la primera es falsa pero esta es verdadera
# else:
#     # código si todas las condiciones son falsas
# ```
#
# **Operadores de comparación:**
# - `==` igual a
# - `!=` diferente de
# - `<` menor que
# - `>` mayor que
# - `<=` menor o igual
# - `>=` mayor o igual

# %%
# Ejemplos de condicionales

# Ejemplo 1: if simple
edad = 18
if edad >= 18:
    print("Eres mayor de edad")

# Ejemplo 2: if-else
temperatura = 25
if temperatura > 30:
    print("Hace calor")
else:
    print("La temperatura es agradable")

# Ejemplo 3: if-elif-else
nota = 85

if nota >= 90:
    print("¡Excelente! Tienes una A")
elif nota >= 80:
    print("Muy bien! Tienes una B")
elif nota >= 70:
    print("Bien! Tienes una C")
elif nota >= 60:
    print("Suficiente! Tienes una D")
else:
    print("Necesitas estudiar más. Tienes una F")

# Ejemplo 4: Múltiples condiciones
llueve = False
tengo_paraguas = True

if llueve and tengo_paraguas:
    print("Puedo salir tranquilo")
elif llueve and not tengo_paraguas:
    print("Mejor me quedo en casa")
else:
    print("¡Perfecto para salir!")
# Out:
# Eres mayor de edad
# La temperatura es agradable
# Muy bien! Tienes una B
# ¡Perfecto para salir!

# %% [markdown]
# ## Bucles for 🔄
#
# El **bucle for** se usa para repetir código un número determinado de veces o para recorrer elementos de una lista, string, etc.
#
# **Sintaxis:**
# ```python
# for variable in secuencia:
#     # código a repetir
# ```
#
# **Funciones útiles:**
# - `range(n)`: genera números del 0 al n-1
# - `range(inicio, fin)`: del inicio al fin-1
# - `range(inicio, fin, paso)`: con incrementos personalizados

# %%
# Ejemplos de bucles for

# Ejemplo 1: for con range()
print("Contando del 1 al 5:")
for i in range(1, 6):
    print(f"Número: {i}")

print("\n" + "="*30 + "\n")

# Ejemplo 2: for con una lista
frutas = ["manzana", "banana", "naranja", "uva"]
print("Mis frutas favoritas:")
for fruta in frutas:
    print(f"- {fruta}")

print("\n" + "="*30 + "\n")

# Ejemplo 3: for con string
palabra = "Python"
print("Letras de la palabra 'Python':")
for letra in palabra:
    print(f"Letra: {letra}")

print("\n" + "="*30 + "\n")

# Ejemplo 4: for con enumerate (para obtener índice y valor)
colores = ["rojo", "verde", "azul"]
print("Lista numerada de colores:")
for indice, color in enumerate(colores, 1):
    print(f"{indice}. {color}")

print("\n" + "="*30 + "\n")

# Ejemplo 5: for con rango personalizado
print("Números pares del 0 al 10:")
for numero in range(0, 11, 2):  # inicio, fin, paso
    print(numero, end=" ")
print()  # salto de línea
# Out:
# Contando del 1 al 5:
# Número: 1
# Número: 2
# Número: 3
# Número: 4
# Número: 5
#
# ...
#
# Mis frutas favoritas:
# - manzana
# - banana
# - naranja
# - uva
#
# ...
#
# Letras de la palabra 'Python':
# Letra: P
# Letra: y
# Letra: t
# Letra: h
# Letra: o
# Letra: n
#
# ...
#
# Lista numerada de colores:
# 1. rojo
# 2. verde
# 3. azul
#
# ...
#
# Números pares del 0 al 10:
# 0 2 4 6 8 10

# %% [markdown]
# ## Bucles while ⏰
#
# El **bucle while** repite código mientras una condición sea verdadera.
# Es útil cuando no sabemos exactamente cuántas veces queremos repetir algo.
#
# **Sintaxis:**
# ```python
# while condición:
#     # código a repetir
#     # ¡IMPORTANTE! Actualizar la condición para evitar bucles infinitos
# ```
#
# **⚠️ Cuidado:** Siempre asegúrate de que la condición eventualmente se vuelva falsa, o tendrás un bucle infinito.

# %%
# Ejemplos de bucles while

# Ejemplo 1: Contador simple
print("Contando hacia atrás:")
contador = 5
while contador > 0:
    print(f"Quedan {contador} segundos...")
    contador -= 1  # Esto es igual a: contador = contador - 1
print("¡Tiempo!")

print("\n" + "="*30 + "\n")

# Ejemplo 2: Acumular valores
print("Sumando números del 1 al 5:")
numero = 1
suma_total = 0
while numero <= 5:
    print(f"Sumando {numero}: {suma_total} + {numero} = {suma_total + numero}")
    suma_total += numero  # suma_total = suma_total + numero
    numero += 1
print(f"Suma total: {suma_total}")

print("\n" + "="*30 + "\n")

# Ejemplo 3: Buscar en una lista
nombres = ["Ana", "Carlos", "María", "Luis", "Pedro"]
buscar = "María"
indice = 0
encontrado = False

print(f"Buscando '{buscar}' en la lista...")
while indice < len(nombres) and not encontrado:
    if nombres[indice] == buscar:
        print(f"¡Encontrado! '{buscar}' está en la posición {indice}")
        encontrado = True
    else:
        print(f"Posición {indice}: {nombres[indice]} - No es el que buscamos")
    indice += 1

if not encontrado:
    print(f"'{buscar}' no se encontró en la lista")

# %% [markdown]
# ## Combinando todo: Funciones + Condicionales + Bucles 🚀
#
# Lo poderoso de Python es poder combinar funciones, condicionales y bucles para crear programas más complejos y útiles.

# %%
# Ejemplo complejo: Sistema de calificaciones

def evaluar_estudiante(nombre, calificaciones):
    """
    Función que evalua a un estudiante y determina su estado académico
    """
    print(f"\n=== Evaluación de {nombre} ===")
    
    # Mostrar todas las calificaciones
    print("Calificaciones:")
    for i, nota in enumerate(calificaciones, 1):
        print(f"  Examen {i}: {nota}")
    
    # Calcular promedio
    suma = 0
    for nota in calificaciones:
        suma += nota
    promedio = suma / len(calificaciones)
    
    print(f"Promedio: {promedio:.2f}")
    
    # Determinar estado académico
    if promedio >= 90:
        estado = "Excelente"
        mensaje = "¡Felicitaciones! Rendimiento sobresaliente."
    elif promedio >= 80:
        estado = "Muy Bueno"
        mensaje = "Buen trabajo, sigue así."
    elif promedio >= 70:
        estado = "Bueno" 
        mensaje = "Rendimiento aceptable."
    elif promedio >= 60:
        estado = "Suficiente"
        mensaje = "Necesitas mejorar un poco más."
    else:
        estado = "Insuficiente"
        mensaje = "Debes esforzarte más. ¡Tú puedes!"
    
    print(f"Estado: {estado}")
    print(f"Consejo: {mensaje}")
    
    return promedio, estado

def analizar_clase(estudiantes_datos):
    """
    Analiza el rendimiento de toda la clase
    """
    print("\n" + "="*50)
    print("ANÁLISIS GENERAL DE LA CLASE")
    print("="*50)
    
    todos_promedios = []
    
    # Evaluar cada estudiante
    for nombre, calificaciones in estudiantes_datos.items():
        promedio, estado = evaluar_estudiante(nombre, calificaciones)
        todos_promedios.append(promedio)
    
    # Estadísticas generales
    promedio_clase = sum(todos_promedios) / len(todos_promedios)
    mejor_promedio = max(todos_promedios)
    menor_promedio = min(todos_promedios)
    
    print(f"\n=== ESTADÍSTICAS GENERALES ===")
    print(f"Promedio de la clase: {promedio_clase:.2f}")
    print(f"Mejor promedio: {mejor_promedio:.2f}")
    print(f"Menor promedio: {menor_promedio:.2f}")
    
    # Contar estudiantes por categoría
    excelentes = 0
    aprobados = 0
    reprobados = 0
    
    for promedio in todos_promedios:
        if promedio >= 90:
            excelentes += 1
        if promedio >= 60:
            aprobados += 1
        else:
            reprobados += 1
    
    print(f"\nResumen:")
    print(f"- Estudiantes excelentes (≥90): {excelentes}")
    print(f"- Estudiantes aprobados (≥60): {aprobados}")
    print(f"- Estudiantes reprobados (<60): {reprobados}")

# Datos de ejemplo
datos_estudiantes = {
    "Ana": [85, 92, 78, 88],
    "Carlos": [76, 82, 79, 85],
    "María": [95, 98, 92, 96],
    "Luis": [65, 58, 72, 69],
    "Sofia": [88, 91, 87, 89]
}

# Ejecutar el análisis
analizar_clase(datos_estudiantes)

# %% [markdown]
# ## 🏋️ Ejercicios Prácticos
#
# ¡Es hora de poner en práctica todo lo aprendido! Resuelve estos ejercicios que combinan funciones, condicionales y bucles.

# %% [markdown]
# ### Ejercicio 1: Funciones Básicas 🎯
#
# Crea las siguientes funciones:
#
# 1. `calcular_imc(peso, altura)` - Calcula el índice de masa corporal (IMC = peso / altura²)
# 2. `clasificar_imc(imc)` - Clasifica el IMC:
#    - Menor a 18.5: "Bajo peso"
#    - 18.5 a 24.9: "Peso normal"
#    - 25.0 a 29.9: "Sobrepeso"
#    - 30.0 o más: "Obesidad"
# 3. `evaluar_salud(peso, altura)` - Combina las dos funciones anteriores y muestra un mensaje completo
#
# Prueba tus funciones con diferentes valores.

# %%
# Ejercicio 1 - Escribe tu solución aquí

# Tu código aquí...

# %% [markdown]
# ### Ejercicio 2: Tablas de Multiplicar 📊
#
# Crea una función llamada `mostrar_tabla(numero, hasta=10)` que:
#
# 1. Reciba un número y muestre su tabla de multiplicar
# 2. Por defecto muestre hasta el 10, pero permita cambiar el límite
# 3. Use un bucle `for` para generar la tabla
# 4. Muestre el resultado en formato: "5 x 3 = 15"
#
# Luego crea otra función `mostrar_varias_tablas(lista_numeros)` que muestre las tablas de varios números.

# %%
# Ejercicio 2 - Escribe tu solución aquí

# Tu código aquí...

# %% [markdown]
# ### Ejercicio 3: Juego de Adivinanza 🎲
#
# Crea una función `juego_adivinanza()` que:
#
# 1. Genere un número aleatorio entre 1 y 100 (usa `import random` y `random.randint(1, 100)`)
# 2. Use un bucle `while` para pedir al usuario que adivine el número
# 3. Dé pistas: "Muy alto", "Muy bajo" o "¡Correcto!"
# 4. Cuente los intentos y muestre el resultado final
# 5. Para simular la entrada del usuario, usa una lista de números predefinida
#
# **Pista:** Para simular el juego sin entrada real del usuario, puedes usar algo como:
# ```python
# intentos_simulados = [50, 75, 63, 69, 66, 68]  # Lista de intentos
# ```

# %%
# Ejercicio 3 - Escribe tu solución aquí

# Tu código aquí...

# %% [markdown]
# ### Ejercicio 4: Calculadora Avanzada 🧮
#
# Crea un sistema de calculadora que incluya:
#
# 1. Una función `menu()` que muestre las opciones disponibles
# 2. Funciones para cada operación: `sumar()`, `restar()`, `multiplicar()`, `dividir()`, `potencia()`
# 3. Una función `calculadora()` que:
#    - Use un bucle para mantener la calculadora activa
#    - Use condicionales para elegir la operación
#    - Maneje errores (como división por cero)
#    - Permita salir con una opción especial
#
# **Opciones del menú:**
# - 1: Sumar
# - 2: Restar
# - 3: Multiplicar
# - 4: Dividir
# - 5: Potencia
# - 6: Salir
#
# Para simular la entrada del usuario, usa una lista de opciones predefinida.

# %%
# Ejercicio 4 - Escribe tu solución aquí

# Tu código aquí...

# %% [markdown]
# ### Ejercicio 5: Desafío - Analizador de Texto 📝
#
# ¡Desafío avanzado! Crea un analizador de texto con las siguientes funciones:
#
# 1. `contar_palabras(texto)` - Cuenta el número de palabras
# 2. `contar_vocales(texto)` - Cuenta cuántas vocales hay
# 3. `palabra_mas_larga(texto)` - Encuentra la palabra más larga
# 4. `contar_frecuencia_letras(texto)` - Cuenta cuántas veces aparece cada letra
# 5. `es_palindromo(palabra)` - Verifica si una palabra es palíndromo
# 6. `analizar_texto_completo(texto)` - Función principal que use todas las anteriores
#
# **Texto de prueba:**
# ```python
# texto = "Python es un lenguaje de programacion poderoso y versatil"
# ```
#
# **Bonus:** Haz que el analizador ignore mayúsculas/minúsculas y signos de puntuación.

# %%
# Ejercicio 5 - Escribe tu solución aquí

# Tu código aquí...

# %% [markdown]
# ---
#
# ## 💡 Soluciones de los Ejercicios
#
# ¡Intenta resolver los ejercicios por tu cuenta primero!
# Después puedes revisar estas soluciones para comparar y aprender.

# %%
# Solución Ejercicio 1: Funciones Básicas (IMC)

def calcular_imc(peso, altura):
    """Calcula el índice de masa corporal"""
    imc = peso / (altura ** 2)
    return imc

def clasificar_imc(imc):
    """Clasifica el IMC según rangos estándar"""
    if imc < 18.5:
        return "Bajo peso"
    elif imc <= 24.9:
        return "Peso normal"
    elif imc <= 29.9:
        return "Sobrepeso"
    else:
        return "Obesidad"

def evaluar_salud(peso, altura):
    """Evaluación completa de salud basada en IMC"""
    print(f"\n=== Evaluación de Salud ===")
    print(f"Peso: {peso} kg")
    print(f"Altura: {altura} m")
    
    imc = calcular_imc(peso, altura)
    clasificacion = clasificar_imc(imc)
    
    print(f"IMC: {imc:.2f}")
    print(f"Clasificación: {clasificacion}")
    
    # Consejos adicionales
    if clasificacion == "Peso normal":
        print("¡Excelente! Mantén tus hábitos saludables.")
    elif clasificacion == "Bajo peso":
        print("Considera consultar a un nutricionista.")
    elif clasificacion == "Sobrepeso":
        print("Una dieta balanceada y ejercicio pueden ayudar.")
    else:  # Obesidad
        print("Recomendamos consultar con un profesional de la salud.")

# Pruebas
print("Probando las funciones:")
evaluar_salud(70, 1.75)
evaluar_salud(85, 1.80)
evaluar_salud(55, 1.65)
# Out:
# Probando las funciones:
#
# === Evaluación de Salud ===
# Peso: 70 kg
# Altura: 1.75 m
# IMC: 22.86
# Clasificación: Peso normal
# ¡Excelente! Mantén tus hábitos saludables.
#
# === Evaluación de Salud ===
# Peso: 85 kg
# Altura: 1.8 m
# IMC: 26.23
# Clasificación: Sobrepeso
# Una dieta balanceada y ejercicio pueden ayudar.
#
# === Evaluación de Salud ===
# Peso: 55 kg
# Altura: 1.65 m
# IMC: 20.20
# Clasificación: Peso normal
# ¡Excelente! Mantén tus hábitos saludables.

# %%
# Solución Ejercicio 2: Tablas de Multiplicar

def mostrar_tabla(numero, hasta=10):
    """Muestra la tabla de multiplicar de un número"""
    print(f"\n=== Tabla del {numero} ===")
    for i in range(1, hasta + 1):
        resultado = numero * i
        print(f"{numero} x {i} = {resultado}")

def mostrar_varias_tablas(lista_numeros):
    """Muestra las tablas de multiplicar de varios números"""
    print("TABLAS DE MULTIPLICAR")
    print("=" * 40)
    
    for numero in lista_numeros:
        mostrar_tabla(numero)
        print()  # Línea en blanco entre tablas

# Pruebas
print("Tabla individual:")
mostrar_tabla(7)

print("\nTabla con límite personalizado:")
mostrar_tabla(3, 5)

print("\nVarias tablas:")
mostrar_varias_tablas([2, 5, 9])
